# %%
import numpy as np

# %% [markdown]
# numpy operations

# %%
arr = np.arange(0,10)
print(arr)
print(arr+arr)
print(arr*arr)
print(arr-arr)
print(arr/arr)
print(1/arr)
print(arr**3)

# %% [markdown]
# universal array functions<br>
# square root

# %%
print(np.sqrt(arr))

# %% [markdown]
# e^n

# %%
print(np.exp(arr))

# %% [markdown]
# max

# %%
print(np.max(arr))

# %% [markdown]
# sin

# %%
print(np.sin(arr))

# %% [markdown]
# log

# %%
print(np.log(arr))
